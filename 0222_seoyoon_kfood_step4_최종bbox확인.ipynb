# %%
import random
from matplotlib import pyplot as plt
import cv2
import numpy as np
from PIL import Image
import os
import json

# jupyter notebook 내 그래프를 바로 그리기 위한 설정
# %matplotlib inline
# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
# 나눔고딕 폰트 적용
plt.rcParams['font.family'] = 'Malgun Gothic'

count=1
 
plt.figure('seoyoon',figsize = (30,50))
# plt.figure('seoyoon').clf()


for i in os.listdir('./kfood_sy'):
    for j in os.listdir(f'./kfood_sy/{i}'):
        print(j)
        plt.subplot(17,2,count)
        img_list= os.listdir(f'./kfood_sy/{i}/{j}/image')
        # print(img_list[:10])
        
        # 랜덤으로 이미지 한개 뽑기 
        choice = random.choice(img_list) 
        print(choice) # 'B080285XX_02222.jpg' 또는 'Img_133_0310.jpg'
        
        #  PIL Image를 numpy array 처리
        img = Image.open(f'./kfood_sy/{i}/{j}/image/'+choice) # 뽑은 이미지 1개 PIL로 읽기
        imgArray = np.array(img) 
        img_shape = imgArray.shape 
        print(imgArray.shape) # (1800, 2700, 3) = (H,W,channel수)
        
        # case1 : json
        if 'Img'  not in choice:
            with open(f'./kfood_sy/{i}/{j}/label/'+choice[:-4]+'.json',mode='r',encoding='UTF8') as f:
                data = json.load(f)
                print(data[0])
                print(json.dumps(data, indent="\t") ) # json을 더 예쁘게 출력하기 위한 
            x_center = float(data[0]['Point(x,y)'].split(',')[0]) * imgArray.shape[1] # x_center*W - bbox의 x센터
            y_center = float(data[0]['Point(x,y)'].split(',')[1]) * imgArray.shape[0] # y_center*H - bbox의 y센터

            y_width = float(data[0]['W']) # bbox의 w
            y_height = float(data[0]['H']) # bbox의 h

            coco_width = y_width * imgArray.shape[1] # bbox의 픽셀단위 w
            coco_height = y_height * imgArray.shape[0] # bbox의 픽셀단위 h
            print(coco_width, coco_height)

            start_x = x_center - (coco_width / 2) # start x좌표
            start_y = y_center - (coco_height / 2) # start y좌표
            
            end_x = x_center + (coco_width / 2) # end x좌표
            end_y = y_center + (coco_height / 2) # end y좌표

            print(start_x, start_y)
            
            # 시각화
            img = cv2.rectangle(imgArray, (int(start_x), int(start_y)), (int(end_x), int(end_y)), (0,255,0), 3).copy() # (이미지, start, end, color, thickness)
            # cv2.putText(image, bbox_mess, (c1[0], int(np.float32(c1[1] - 2))), cv2.FONT_HERSHEY_SIMPLEX, fontScale, (0, 0, 0), bbox_thick // 2, lineType=cv2.LINE_AA)
            plt.title(f'{j}, {img_shape}, {((start_x,start_y),(end_x, end_y))}')
            plt.imshow(img)
            count +=1        
                                
        # case 2 : properties
        else: 
            with open(f'./kfood_sy/{i}/{j}/label/crop_area.properties',mode='r',encoding='UTF8') as f:
                data = f.read()
                data_list = data.split('\n')[:-1] # '[Img_133_0012=4,96,322,445' , ... ]
            for bbox in data_list:
                if choice[:-4] in bbox:
                    xy = bbox.split('=')[1].split(',') # ['4','96','322','445']
                    print(xy)
                else:
                    continue
            img = cv2.rectangle(imgArray, (int(xy[0]), int(xy[1])), (int(xy[0])+int(xy[2]), int(xy[1])+int(xy[3])), (0,255,0), 3).copy() # (이미지, start, end, color, thickness)
            plt.title(f'{j}, {img_shape}, {((start_x,start_y),(end_x, end_y))}')
            plt.imshow(img)
            count +=1 
            
    plt.tight_layout()
# Out:
# 떡갈비
# B080285XX_10207.jpg
# (1620, 2430, 3)
# {'Code Name': 'B080285XX_10207.jpg', 'Name': 'hambagseuteikeu', 'W': '0.507407407407407', 'H': '0.316666666666667', 'File Format': 'jpg', 'Cat 1': '08', 'Cat 2': '02', 'Cat 3': '85', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.531069958847737,0.410185185185185', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B080285XX_10207.jpg",
# 		"Name": "hambagseuteikeu",
# 		"W": "0.507407407407407",
# 		"H": "0.316666666666667",
# 		"File Format": "jpg",
# 		"Cat 1": "08",
# 		"Cat 2": "02",
# 		"Cat 3": "85",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.531069958847737,0.410185185185185",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1232.9999999999989 513.0000000000006
# 674.0000000000015 407.9999999999994
# 불고기
# B100565XX_01133.jpg
# (1608, 2430, 3)
# {'Code Name': 'B100565XX_01133.jpg', 'Name': 'soegogibokk-eum', 'W': '0.716049382716049', 'H': '0.778606965174129', 'File Format': 'jpg', 'Cat 1': '10', 'Cat 2': '05', 'Cat 3': '65', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.641975308641975,0.610696517412935', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B100565XX_01133.jpg",
# 		"Name": "soegogibokk-eum",
# 		"W": "0.716049382716049",
# 		"H": "0.778606965174129",
# 		"File Format": "jpg",
# 		"Cat 1": "10",
# 		"Cat 2": "05",
# 		"Cat 3": "65",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.641975308641975,0.610696517412935",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1739.999999999999 1251.9999999999993
# 689.9999999999998 355.9999999999998
# 장어구이
# B080137XX_00030.jpg
# (1801, 2700, 3)
# {'Code Name': 'B080137XX_00030.jpg', 'Name': 'jang-eogu-i', 'W': '1.000000', 'H': '0.617773', 'File Format': 'jpg', 'Cat 1': '08', 'Cat 2': '01', 'Cat 3': '37', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.500000,0.619736', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B080137XX_00030.jpg",
# 		"Name": "jang-eogu-i",
# 		"W": "1.000000",
# 		"H": "0.617773",
# 		"File Format": "jpg",
# 		"Cat 1": "08",
# 		"Cat 2": "01",
# 		"Cat 3": "37",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.500000,0.619736",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 2700.0 1112.609173
# 0.0 559.8399495
# 쪽갈비구이
# B080279XX_11314.jpg
# (1166, 1748, 3)
# {'Code Name': 'B080279XX_11314.jpg', 'Name': 'jjoggalbigu-i', 'W': '0.632151029748284', 'H': '0.999142367066895', 'File Format': 'jpg', 'Cat 1': '08', 'Cat 2': '02', 'Cat 3': '79', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.683924485125858,0.500428816466552', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B080279XX_11314.jpg",
# 		"Name": "jjoggalbigu-i",
# 		"W": "0.632151029748284",
# 		"H": "0.999142367066895",
# 		"File Format": "jpg",
# 		"Cat 1": "08",
# 		"Cat 2": "02",
# 		"Cat 3": "79",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.683924485125858,0.500428816466552",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1105.0000000000005 1164.9999999999995
# 642.9999999999995 0.9999999999998863
# 훈제오리
# A270204XX_01018.jpg
# (2700, 2133, 3)
# {'Code Name': 'A270204XX_01018.jpg', 'Name': 'hunje-oli', 'W': '0.668265', 'H': '0.324563', 'File Format': 'jpg', 'Cat 1': '27', 'Cat 2': '02', 'Cat 3': '04', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.559993,0.612278', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "A270204XX_01018.jpg",
# 		"Name": "hunje-oli",
# 		"W": "0.668265",
# 		"H": "0.324563",
# 		"File Format": "jpg",
# 		"Cat 1": "27",
# 		"Cat 2": "02",
# 		"Cat 3": "04",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.559993,0.612278",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1425.409245 876.3201
# 481.76044649999983 1214.99055
# 미역국
# B050727_50019.jpg
# (1500, 1125, 3)
# {'Code Name': 'B050727_50019.jpg', 'Name': 'miyeoggug', 'W': '0.832640', 'H': '0.536147', 'File Format': 'jpg', 'Cat 1': '05', 'Cat 2': '07', 'Cat 3': '27', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.498400,0.597913', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B050727_50019.jpg",
# 		"Name": "miyeoggug",
# 		"W": "0.832640",
# 		"H": "0.536147",
# 		"File Format": "jpg",
# 		"Cat 1": "05",
# 		"Cat 2": "07",
# 		"Cat 3": "27",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.498400,0.597913",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 936.72 804.2205
# 92.34000000000003 494.75925
# 해장국
# B050632XX_01245.jpg
# (2430, 1822, 3)
# {'Code Name': 'B050632XX_01245.jpg', 'Name': 'haejang-gug', 'W': '0.93139407244786', 'H': '0.469958847736625', 'File Format': 'jpg', 'Cat 1': '05', 'Cat 2': '06', 'Cat 3': '32', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.503567508232711,0.585185185185185', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B050632XX_01245.jpg",
# 		"Name": "haejang-gug",
# 		"W": "0.93139407244786",
# 		"H": "0.469958847736625",
# 		"File Format": "jpg",
# 		"Cat 1": "05",
# 		"Cat 2": "06",
# 		"Cat 3": "32",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.503567508232711,0.585185185185185",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1697.000000000001 1141.9999999999986
# 68.99999999999898 851.0000000000002
# 깍두기
# B150203_50337.jpg
# (899, 1350, 3)
# {'Code Name': 'B150203_50337.jpg', 'Name': 'mugimchi', 'W': '0.773333333333333', 'H': '0.707452725250278', 'File Format': 'jpg', 'Cat 1': '15', 'Cat 2': '02', 'Cat 3': '03', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.387407407407407,0.566184649610678', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B150203_50337.jpg",
# 		"Name": "mugimchi",
# 		"W": "0.773333333333333",
# 		"H": "0.707452725250278",
# 		"File Format": "jpg",
# 		"Cat 1": "15",
# 		"Cat 2": "02",
# 		"Cat 3": "03",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.387407407407407,0.566184649610678",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1043.9999999999995 636.0
# 0.9999999999996589 190.99999999999955
# 배추김치
# B150105_50852.jpg
# (899, 1350, 3)
# {'Code Name': 'B150105_50852.jpg', 'Name': 'baechugimchi', 'W': '0.666666666666667', 'H': '0.848720800889878', 'File Format': 'jpg', 'Cat 1': '15', 'Cat 2': '01', 'Cat 3': '05', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.457037037037037,0.544493882091212', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B150105_50852.jpg",
# 		"Name": "baechugimchi",
# 		"W": "0.666666666666667",
# 		"H": "0.848720800889878",
# 		"File Format": "jpg",
# 		"Cat 1": "15",
# 		"Cat 2": "01",
# 		"Cat 3": "05",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.457037037037037,0.544493882091212",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 900.0000000000005 763.0000000000003
# 166.99999999999977 107.99999999999937
# 숙주나물
# B130147XX_01136.jpg
# (1801, 2700, 3)
# {'Code Name': 'B130147XX_01136.jpg', 'Name': 'sugjunamul', 'W': '0.705152', 'H': '0.762499', 'File Format': 'jpg', 'Cat 1': '13', 'Cat 2': '01', 'Cat 3': '47', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.600820,0.458406', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B130147XX_01136.jpg",
# 		"Name": "sugjunamul",
# 		"W": "0.705152",
# 		"H": "0.762499",
# 		"File Format": "jpg",
# 		"Cat 1": "13",
# 		"Cat 2": "01",
# 		"Cat 3": "47",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.600820,0.458406",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1903.9104 1373.2606990000002
# 670.2588000000002 138.9588564999999
# 군만두
# B031103_50355.jpg
# (1350, 1244, 3)
# {'Code Name': 'B031103_50355.jpg', 'Name': 'gunmandu', 'W': '0.812700964630225', 'H': '0.618518518518518', 'File Format': 'jpg', 'Cat 1': '03', 'Cat 2': '11', 'Cat 3': '03', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.492363344051447,0.357407407407407', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B031103_50355.jpg",
# 		"Name": "gunmandu",
# 		"W": "0.812700964630225",
# 		"H": "0.618518518518518",
# 		"File Format": "jpg",
# 		"Cat 1": "03",
# 		"Cat 2": "11",
# 		"Cat 3": "03",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.492363344051447,0.357407407407407",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	},
# 	{
# 		"Code Name": "B031103_50355.jpg",
# 		"Name": "gunmandu",
# 		"W": "0.653536977491961",
# 		"H": "0.460740740740741",
# 		"File Format": "jpg",
# 		"Cat 1": "03",
# 		"Cat 2": "11",
# 		"Cat 3": "03",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.327572347266881,0.234074074074074",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1010.9999999999999 834.9999999999993
# 107.00000000000017 64.99999999999977
# 찐만두
# Img_049_0426.jpg
# (400, 444, 3)
# ['101', '62', '266', '241']
# 비빔국수
# B030114_50215.jpg
# (1350, 900, 3)
# {'Code Name': 'B030114_50215.jpg', 'Name': 'bibimgugsu', 'W': '0.998888888888889', 'H': '0.828148148148148', 'File Format': 'jpg', 'Cat 1': '03', 'Cat 2': '01', 'Cat 3': '14', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.500555555555556,0.532592592592593', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B030114_50215.jpg",
# 		"Name": "bibimgugsu",
# 		"W": "0.998888888888889",
# 		"H": "0.828148148148148",
# 		"File Format": "jpg",
# 		"Cat 1": "03",
# 		"Cat 2": "01",
# 		"Cat 3": "14",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.500555555555556,0.532592592592593",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 899.0000000000001 1117.9999999999998
# 1.000000000000341 160.00000000000057
# 비빔냉면
# B030303_50579.jpg
# (900, 1350, 3)
# {'Code Name': 'B030303_50579.jpg', 'Name': 'bibimnaengmyeon', 'W': '0.586666666666667', 'H': '0.675555555555556', 'File Format': 'jpg', 'Cat 1': '03', 'Cat 2': '03', 'Cat 3': '03', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.453333333333333,0.521111111111111', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B030303_50579.jpg",
# 		"Name": "bibimnaengmyeon",
# 		"W": "0.586666666666667",
# 		"H": "0.675555555555556",
# 		"File Format": "jpg",
# 		"Cat 1": "03",
# 		"Cat 2": "03",
# 		"Cat 3": "03",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.453333333333333,0.521111111111111",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 792.0000000000005 608.0000000000005
# 215.99999999999932 164.99999999999966
# 우동
# B030811XX_00762.jpg
# (1800, 2700, 3)
# {'Code Name': 'B030811XX_00762.jpg', 'Name': 'udong', 'W': '0.758519', 'H': '0.475556', 'File Format': 'jpg', 'Cat 1': '03', 'Cat 2': '08', 'Cat 3': '11', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.518815,0.647556', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B030811XX_00762.jpg",
# 		"Name": "udong",
# 		"W": "0.758519",
# 		"H": "0.475556",
# 		"File Format": "jpg",
# 		"Cat 1": "03",
# 		"Cat 2": "08",
# 		"Cat 3": "11",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.518815,0.647556",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 2048.0013000000004 856.0007999999999
# 376.7998499999999 737.6004
# 짜장면
# B031017XX_01256.jpg
# (1800, 2700, 3)
# {'Code Name': 'B031017XX_01256.jpg', 'Name': 'jjajangmyeon', 'W': '0.624000', 'H': '0.936000', 'File Format': 'jpg', 'Cat 1': '03', 'Cat 2': '10', 'Cat 3': '17', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.673748,0.483422', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B031017XX_01256.jpg",
# 		"Name": "jjajangmyeon",
# 		"W": "0.624000",
# 		"H": "0.936000",
# 		"File Format": "jpg",
# 		"Cat 1": "03",
# 		"Cat 2": "10",
# 		"Cat 3": "17",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.673748,0.483422",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1684.8 1684.8000000000002
# 976.7196 27.759599999999978
# 짬뽕
# B031018XX_01577.jpg
# (1800, 2700, 3)
# {'Code Name': 'B031018XX_01577.jpg', 'Name': 'jjamppong', 'W': '0.99962962962963', 'H': '1.000000', 'File Format': 'jpg', 'Cat 1': '03', 'Cat 2': '10', 'Cat 3': '18', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.500185185185185,0.500000', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B031018XX_01577.jpg",
# 		"Name": "jjamppong",
# 		"W": "0.99962962962963",
# 		"H": "1.000000",
# 		"File Format": "jpg",
# 		"Cat 1": "03",
# 		"Cat 2": "10",
# 		"Cat 3": "18",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.500185185185185,0.500000",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 2699.000000000001 1800.0
# 0.9999999999988631 0.0
# 콩국수
# Img_061_0146.jpg
# (500, 375, 3)
# ['20', '220', '336', '280']
# 잡채
# B100208XX_01135.jpg
# (1799, 2700, 3)
# {'Code Name': 'B100208XX_01135.jpg', 'Name': 'jabchae', 'W': '0.958952', 'H': '1.000000', 'File Format': 'jpg', 'Cat 1': '10', 'Cat 2': '02', 'Cat 3': '08', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.479476,0.500000', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B100208XX_01135.jpg",
# 		"Name": "jabchae",
# 		"W": "0.958952",
# 		"H": "1.000000",
# 		"File Format": "jpg",
# 		"Cat 1": "10",
# 		"Cat 2": "02",
# 		"Cat 3": "08",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.479476,0.500000",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 2589.1704 1799.0
# 0.0 0.0
# 회무침
# Img_068_0718.jpg
# (400, 533, 3)
# ['79', '31', '367', '316']
# 알밥
# Img_074_0738.jpg
# (400, 598, 3)
# ['66', '7', '474', '379']
# 주먹밥
# B010710XX_00470.jpg
# (1800, 2700, 3)
# {'Code Name': 'B010710XX_00470.jpg', 'Name': 'jumeogbab', 'W': '0.193830', 'H': '0.277706', 'File Format': 'jpg', 'Cat 1': '01', 'Cat 2': '07', 'Cat 3': '10', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.676856,0.529103', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B010710XX_00470.jpg",
# 		"Name": "jumeogbab",
# 		"W": "0.193830",
# 		"H": "0.277706",
# 		"File Format": "jpg",
# 		"Cat 1": "01",
# 		"Cat 2": "07",
# 		"Cat 3": "10",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.676856,0.529103",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	},
# 	{
# 		"Code Name": "B010710XX_00470.jpg",
# 		"Name": "jumeogbab",
# 		"W": "0.224252",
# 		"H": "0.324639",
# 		"File Format": "jpg",
# 		"Cat 1": "01",
# 		"Cat 2": "07",
# 		"Cat 3": "10",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.859819,0.733797",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	},
# 	{
# 		"Code Name": "B010710XX_00470.jpg",
# 		"Name": "jumeogbab",
# 		"W": "0.232070",
# 		"H": "0.353322",
# 		"File Format": "jpg",
# 		"Cat 1": "01",
# 		"Cat 2": "07",
# 		"Cat 3": "10",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.664687,0.801594",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 523.341 499.87080000000003
# 1565.8407000000002 702.45
# 떡볶이
# B100106_50963.jpg
# (810, 1214, 3)
# {'Code Name': 'B100106_50963.jpg', 'Name': 'tteogbokk-i', 'W': '0.490115321252059', 'H': '0.777777777777778', 'File Format': 'jpg', 'Cat 1': '10', 'Cat 2': '01', 'Cat 3': '06', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.511943986820428,0.574074074074074', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B100106_50963.jpg",
# 		"Name": "tteogbokk-i",
# 		"W": "0.490115321252059",
# 		"H": "0.777777777777778",
# 		"File Format": "jpg",
# 		"Cat 1": "10",
# 		"Cat 2": "01",
# 		"Cat 3": "06",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.511943986820428,0.574074074074074",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 594.9999999999995 630.0000000000002
# 323.9999999999998 149.99999999999977
# 파전
# B090358XX_10663.jpg
# (2186, 1638, 3)
# {'Code Name': 'B090358XX_10663.jpg', 'Name': 'pajeon', 'W': '0.860805860805861', 'H': '0.458828911253431', 'File Format': 'jpg', 'Cat 1': '09', 'Cat 2': '03', 'Cat 3': '58', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.525030525030525,0.650731930466606', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B090358XX_10663.jpg",
# 		"Name": "pajeon",
# 		"W": "0.860805860805861",
# 		"H": "0.458828911253431",
# 		"File Format": "jpg",
# 		"Cat 1": "09",
# 		"Cat 2": "03",
# 		"Cat 3": "58",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.525030525030525,0.650731930466606",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1410.0000000000002 1003.0000000000002
# 154.9999999999999 921.0000000000008
# 곱창전골
# B060601_50081.jpg
# (1000, 1500, 3)
# {'Code Name': 'B060601_50081.jpg', 'Name': 'gobchangjeongol', 'W': '0.566633', 'H': '0.544480', 'File Format': 'jpg', 'Cat 1': '06', 'Cat 2': '06', 'Cat 3': '01', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.353090,0.405150', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B060601_50081.jpg",
# 		"Name": "gobchangjeongol",
# 		"W": "0.566633",
# 		"H": "0.544480",
# 		"File Format": "jpg",
# 		"Cat 1": "06",
# 		"Cat 2": "06",
# 		"Cat 3": "01",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.353090,0.405150",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 849.9495000000001 544.48
# 104.66024999999996 132.91000000000003
# 흰죽
# B040152XX_10140.jpg
# (1820, 2430, 3)
# {'Code Name': 'B040152XX_10140.jpg', 'Name': 'huinjug', 'W': '0.884362139917696', 'H': '0.476373626373626', 'File Format': 'jpg', 'Cat 1': '04', 'Cat 2': '01', 'Cat 3': '52', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.557818930041152,0.470604395604396', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B040152XX_10140.jpg",
# 		"Name": "huinjug",
# 		"W": "0.884362139917696",
# 		"H": "0.476373626373626",
# 		"File Format": "jpg",
# 		"Cat 1": "04",
# 		"Cat 2": "01",
# 		"Cat 3": "52",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.557818930041152,0.470604395604396",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 2149.0000000000014 866.9999999999993
# 280.99999999999864 423.000000000001
# 된장찌개
# B060211_50977.jpg
# (1350, 934, 3)
# {'Code Name': 'B060211_50977.jpg', 'Name': 'doenjangjjigae', 'W': '0.822269807280514', 'H': '0.533333333333333', 'File Format': 'jpg', 'Cat 1': '06', 'Cat 2': '02', 'Cat 3': '11', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.41220556745182,0.433333333333333', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B060211_50977.jpg",
# 		"Name": "doenjangjjigae",
# 		"W": "0.822269807280514",
# 		"H": "0.533333333333333",
# 		"File Format": "jpg",
# 		"Cat 1": "06",
# 		"Cat 2": "02",
# 		"Cat 3": "11",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.41220556745182,0.433333333333333",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 768.0000000000001 719.9999999999995
# 0.9999999999998295 224.99999999999977
# 갈비찜
# B070201_50502.jpg
# (1000, 1500, 3)
# {'Code Name': 'B070201_50502.jpg', 'Name': 'galbijjim', 'W': '1.000000', 'H': '0.868330', 'File Format': 'jpg', 'Cat 1': '07', 'Cat 2': '02', 'Cat 3': '01', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.500000,0.565835', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B070201_50502.jpg",
# 		"Name": "galbijjim",
# 		"W": "1.000000",
# 		"H": "0.868330",
# 		"File Format": "jpg",
# 		"Cat 1": "07",
# 		"Cat 2": "02",
# 		"Cat 3": "01",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.500000,0.565835",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1500.0 868.33
# 0.0 131.6699999999999
# 순대
# Img_130_0717.jpg
# (400, 600, 3)
# ['358', '0', '242', '296']
# 족발
# B110242XX_01763.jpg
# (1800, 2700, 3)
# {'Code Name': 'B110242XX_01763.jpg', 'Name': 'jogbal', 'W': '0.575667', 'H': '0.579756', 'File Format': 'jpg', 'Cat 1': '11', 'Cat 2': '02', 'Cat 3': '42', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.531652,0.545789', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B110242XX_01763.jpg",
# 		"Name": "jogbal",
# 		"W": "0.575667",
# 		"H": "0.579756",
# 		"File Format": "jpg",
# 		"Cat 1": "11",
# 		"Cat 2": "02",
# 		"Cat 3": "42",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.531652,0.545789",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1554.3009000000002 1043.5608000000002
# 658.3099499999998 460.6397999999998
# 해물찜
# B070127_50300.jpg
# (900, 1350, 3)
# {'Code Name': 'B070127_50300.jpg', 'Name': 'agwijjim', 'W': '0.75037037037037', 'H': '0.652222222222222', 'File Format': 'jpg', 'Cat 1': '07', 'Cat 2': '01', 'Cat 3': '27', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.624814814814815,0.673888888888889', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B070127_50300.jpg",
# 		"Name": "agwijjim",
# 		"W": "0.75037037037037",
# 		"H": "0.652222222222222",
# 		"File Format": "jpg",
# 		"Cat 1": "07",
# 		"Cat 2": "01",
# 		"Cat 3": "27",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.624814814814815,0.673888888888889",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1012.9999999999995 586.9999999999999
# 337.00000000000057 313.00000000000017
# 모듬튀김
# Img_142_0957.jpg
# (400, 584, 3)
# ['159', '94', '116', '200']
# 한과
# A020519XX_10268.jpg
# (2430, 1820, 3)
# {'Code Name': 'A020519XX_10268.jpg', 'Name': 'yugwa', 'W': '0.491758241758242', 'H': '0.524279835390946', 'File Format': 'jpg', 'Cat 1': '02', 'Cat 2': '05', 'Cat 3': '19', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.473351648351648,0.505761316872428', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "A020519XX_10268.jpg",
# 		"Name": "yugwa",
# 		"W": "0.491758241758242",
# 		"H": "0.524279835390946",
# 		"File Format": "jpg",
# 		"Cat 1": "02",
# 		"Cat 2": "05",
# 		"Cat 3": "19",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.473351648351648,0.505761316872428",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 895.0000000000005 1273.9999999999989
# 413.9999999999991 592.0000000000006
# 육회
# B270105XX_01822.jpg
# (1620, 2430, 3)
# {'Code Name': 'B270105XX_01822.jpg', 'Name': 'yughoe', 'W': '0.458024691358025', 'H': '0.637037037037037', 'File Format': 'jpg', 'Cat 1': '27', 'Cat 2': '01', 'Cat 3': '05', 'Cat 4': 'xx', 'Annotation Type': 'binding', 'Point(x,y)': '0.489506172839506,0.556172839506173', 'Label': '0', 'Serving Size': 'xx', 'Camera Angle': 'xx', 'Cardinal Angle': 'xx', 'Color of Container': 'xx', 'Material of Container': 'xx', 'Illuminance': 'xx'}
# [
# 	{
# 		"Code Name": "B270105XX_01822.jpg",
# 		"Name": "yughoe",
# 		"W": "0.458024691358025",
# 		"H": "0.637037037037037",
# 		"File Format": "jpg",
# 		"Cat 1": "27",
# 		"Cat 2": "01",
# 		"Cat 3": "05",
# 		"Cat 4": "xx",
# 		"Annotation Type": "binding",
# 		"Point(x,y)": "0.489506172839506,0.556172839506173",
# 		"Label": "0",
# 		"Serving Size": "xx",
# 		"Camera Angle": "xx",
# 		"Cardinal Angle": "xx",
# 		"Color of Container": "xx",
# 		"Material of Container": "xx",
# 		"Illuminance": "xx"
# 	}
# ]
# 1113.0000000000007 1031.9999999999998
# 632.9999999999992 385.00000000000045

# %% [markdown]
# ## 유의 : json 은 w,h, bbox의 위치 정보가 start좌표가 아닌 center 좌표로 나와있어서 계산을 다시 해주었다. case 1: json속 좌표 계산하는 식을 유의하자

# %%
a='apple'
if 'ap' in a:
    print('사과가 있다')
# Out:
# 사과가 있다
